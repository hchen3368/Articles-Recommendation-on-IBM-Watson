# %% [markdown]
# ### Implementing FunkSVD with vectorization.
#
# In this notebook we will take a look at writing our own (vectorized) function that performs FunkSVD.
#
# To test our algorithm, we will run it on the subset of the data we worked with earlier.  Run the cell below to get started.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import sparse
import svd_tests as t
# %matplotlib inline

# Read in the datasets
movies = pd.read_csv('../Content based/movies_clean.csv')
reviews = pd.read_csv('../Content based/reviews_clean.csv')

del movies['Unnamed: 0']
del reviews['Unnamed: 0']

# Create user-by-item matrix
user_items = reviews[['user_id', 'movie_id', 'rating', 'timestamp']]
user_by_movie = user_items.groupby(['user_id', 'movie_id'])['rating'].max().unstack()

# Create data subset
user_movie_subset = user_by_movie[[73486, 75314,  68646, 99685]].dropna(axis=0)
ratings_mat = np.matrix(user_movie_subset)
print(ratings_mat)
# Out:
# [[10. 10. 10. 10.]
#  [10.  4.  9. 10.]
#  [ 8.  9. 10.  5.]
#  [ 9.  8. 10. 10.]
#  [10.  5.  9.  9.]
#  [ 6.  4. 10.  6.]
#  [ 9.  8. 10.  9.]
#  [10.  5.  9.  8.]
#  [ 7.  8. 10.  8.]
#  [ 9.  5.  9.  7.]
#  [ 9.  8. 10.  8.]
#  [ 9. 10. 10.  9.]
#  [10.  9. 10.  8.]
#  [ 5.  8.  5.  8.]
#  [10.  8. 10. 10.]
#  [ 9.  9. 10. 10.]
#  [ 9.  8.  8.  8.]
#  [10.  8.  1. 10.]
#  [ 5.  6. 10. 10.]
#  [ 8.  7. 10.  7.]]

# %% [markdown]
# `1.` We will use the **user_movie_subset** matrix to show that our FunkSVD algorithm will converge.

# %%
def FunkSVD(ratings_mat, latent_features=4, learning_rate=0.0001, iters=100):
    '''
    This function performs matrix factorization using a basic form of FunkSVD with no regularization
    
    INPUT:
    ratings_mat - (numpy array) a matrix with users as rows, movies as columns, and ratings as values
    latent_features - (int) the number of latent features used
    learning_rate - (float) the learning rate 
    iters - (int) the number of iterations
    
    OUTPUT:
    user_mat - (numpy array) a user by latent feature matrix
    movie_mat - (numpy array) a latent feature by movie matrix
    '''
    
    # Set up useful values to be used through the rest of the function
    n_users = ratings_mat.shape[0]
    n_movies = ratings_mat.shape[1]
    num_ratings = np.sum(~np.isnan(ratings_mat)) # total number of ratings in the matrix
    
    # initialize the user and movie matrices with random values
    
    user_mat = np.random.rand(n_users, latent_features) 
    movie_mat = np.random.rand(latent_features, n_movies)
    
    # initialize sse at 0 for first iteration
    sse_accum = 0
    
    # header for running results
    print("Optimization Statistics")
    print("Iterations | Mean Squared Error ")
    
    for i in range(iters):

        # update our sse
        old_sse = sse_accum
        sse_accum = 0 
                    
        # compute the error as the actual minus the dot product of the user and movie latent features
        error = np.nan_to_num(ratings_mat-user_mat@movie_mat)
        # Keep track of the total sum of squared errors for the matrix
        sse_accum = np.sum(np.multiply(error,error))            
        # update the values in each matrix in the direction of the gradient
        user_mat += 2*learning_rate*error@(movie_mat.T)
        movie_mat += 2*learning_rate*(user_mat.T)@error
        # print results for iteration
        print(f'Iteration {i}, Sum of Square Errors is {sse_accum}.')
        
    return user_mat, movie_mat

# %% [markdown]
# `2.` Try out the function on the **user_movie_subset** dataset.  First try 4 latent features, a learning rate of 0.005, and 10 iterations.

# %%
# 4 latent features, lr of 0.005 and 10 iterations
user_mat, movie_mat = FunkSVD(ratings_mat, latent_features=4, learning_rate=0.005, iters=10)
# Out:
# Optimization Statistics
# Iterations | Mean Squared Error
# Iteration 0, Sum of Square Errors is 4695.610448140116.
# Iteration 1, Sum of Square Errors is 2121.256087383552.
# Iteration 2, Sum of Square Errors is 243.37812974910824.
# Iteration 3, Sum of Square Errors is 173.93187463035878.
# Iteration 4, Sum of Square Errors is 169.96950895409245.
# Iteration 5, Sum of Square Errors is 167.82388765616182.
# Iteration 6, Sum of Square Errors is 165.56095342778667.
# Iteration 7, Sum of Square Errors is 163.06199171656374.
# Iteration 8, Sum of Square Errors is 160.2774547976628.
# Iteration 9, Sum of Square Errors is 157.16801660432347.

# %%
#Compare the predicted and actual results
print(np.dot(user_mat, movie_mat).round())
print(ratings_mat)
# Out:
# [[10.  9. 11. 10.]
#  [ 9.  7.  9.  8.]
#  [ 8.  7.  9.  8.]
#  [10.  8. 10.  9.]
#  [ 9.  7.  9.  8.]
#  [ 7.  6.  7.  7.]
#  [ 9.  8. 10.  9.]
#  [ 9.  7.  8.  8.]
#  [ 8.  7.  9.  8.]
#  [ 8.  6.  8.  8.]
#  [ 9.  8. 10.  9.]
#  [ 9.  9. 10.  9.]
#  [10.  8. 10.  9.]
#  [ 7.  5.  7.  7.]
#  [10.  8. 10. 10.]
#  [ 9.  8. 11.  9.]
#  [ 8.  7.  9.  8.]
#  [ 8.  6.  7.  7.]
#  [ 8.  7.  9.  8.]
#  [ 8.  7.  9.  8.]]
# [[10. 10. 10. 10.]
#  [10.  4.  9. 10.]
#  [ 8.  9. 10.  5.]
#  [ 9.  8. 10. 10.]
#  [10.  5.  9.  9.]
#  [ 6.  4. 10.  6.]
#  [ 9.  8. 10.  9.]
#  [10.  5.  9.  8.]
#  [ 7.  8. 10.  8.]
#  [ 9.  5.  9.  7.]
#  [ 9.  8. 10.  8.]
#  [ 9. 10. 10.  9.]
#  [10.  9. 10.  8.]
#  [ 5.  8.  5.  8.]
#  [10.  8. 10. 10.]
#  [ 9.  9. 10. 10.]
#  [ 9.  8.  8.  8.]
#  [10.  8.  1. 10.]
#  [ 5.  6. 10. 10.]
#  [ 8.  7. 10.  7.]]

# %% [markdown]
# **With 10 iterations, the FunkSVD method is going to converge and getting close to the input data.**

# %% [markdown]
# `3.` Let's try out the function again on the **user_movie_subset** dataset.  This time we will again use 4 latent features and a learning rate of 0.005.  However, let's bump up the number of iterations to 250.

# %%
#4 latent features, lr of 0.005 and 250 iterations
user_mat, movie_mat = FunkSVD(ratings_mat, latent_features=4, learning_rate=0.005, iters=250)
# Out:
# Optimization Statistics
# Iterations | Mean Squared Error
# Iteration 0, Sum of Square Errors is 4826.222302182867.
# Iteration 1, Sum of Square Errors is 2388.406437798486.
# Iteration 2, Sum of Square Errors is 298.2232240809206.
# Iteration 3, Sum of Square Errors is 184.21639178115743.
# Iteration 4, Sum of Square Errors is 175.24141290394027.
# Iteration 5, Sum of Square Errors is 172.99219125690047.
# Iteration 6, Sum of Square Errors is 171.50509490766095.
# Iteration 7, Sum of Square Errors is 170.11729557964387.
# Iteration 8, Sum of Square Errors is 168.67304195874826.
# Iteration 9, Sum of Square Errors is 167.11532461816952.
# Iteration 10, Sum of Square Errors is 165.4132178115434.
# Iteration 11, Sum of Square Errors is 163.5422056173107.
# Iteration 12, Sum of Square Errors is 161.47920420928526.
# Iteration 13, Sum of Square Errors is 159.20120120775312.
# Iteration 14, Sum of Square Errors is 156.684977799582.
# Iteration 15, Sum of Square Errors is 153.90721119872077.
# Iteration 16, Sum of Square Errors is 150.84480157285364.
# Iteration 17, Sum of Square Errors is 147.47541761653986.
# Iteration 18, Sum of Square Errors is 143.77830678158736.
# Iteration 19, Sum of Square Errors is 139.73543668667526.
# Iteration 20, Sum of Square Errors is 135.3330375923441.
# Iteration 21, Sum of Square Errors is 130.5635978442523.
# Iteration 22, Sum of Square Errors is 125.42831444355929.
# Iteration 23, Sum of Square Errors is 119.93990833656795.
# Iteration 24, Sum of Square Errors is 114.1255735424599.
# Iteration 25, Sum of Square Errors is 108.02965066411515.
# Iteration 26, Sum of Square Errors is 101.71543296649055.
# Iteration 27, Sum of Square Errors is 95.26539091356771.
# Iteration 28, Sum of Square Errors is 88.779124448743.
# Iteration 29, Sum of Square Errors is 82.36860069292425.
# Iteration 30, Sum of Square Errors is 76.15073384612265.
# Iteration 31, Sum of Square Errors is 70.23803766829784.
# Iteration 32, Sum of Square Errors is 64.72873595084235.
# Iteration 33, Sum of Square Errors is 59.698094615111515.
# Iteration 34, Sum of Square Errors is 55.19263341106126.
# Iteration 35, Sum of Square Errors is 51.228255029801765.
# Iteration 36, Sum of Square Errors is 47.792388832242466.
# Iteration 37, Sum of Square Errors is 44.849324967986746.
# Iteration 38, Sum of Square Errors is 42.34732973690142.
# Iteration 39, Sum of Square Errors is 40.22602979867996.
# Iteration 40, Sum of Square Errors is 38.422864017951206.
# Iteration 41, Sum of Square Errors is 36.87792381568144.
# Iteration 42, Sum of Square Errors is 35.53701899350585.
# Iteration 43, Sum of Square Errors is 34.353176014818516.
# Iteration 44, Sum of Square Errors is 33.28695965906127.
# Iteration 45, Sum of Square Errors is 32.30603911094106.
# Iteration 46, Sum of Square Errors is 31.384356986697355.
# Iteration 47, Sum of Square Errors is 30.501161298859515.
# Iteration 48, Sum of Square Errors is 29.640063646126485.
# Iteration 49, Sum of Square Errors is 28.788210031169847.
# Iteration 50, Sum of Square Errors is 27.93559781823172.
# Iteration 51, Sum of Square Errors is 27.07454030720759.
# Iteration 52, Sum of Square Errors is 26.19926360145709.
# Iteration 53, Sum of Square Errors is 25.30561344152644.
# Iteration 54, Sum of Square Errors is 24.390848261130362.
# Iteration 55, Sum of Square Errors is 23.45349607554217.
# Iteration 56, Sum of Square Errors is 22.493255262089345.
# Iteration 57, Sum of Square Errors is 21.51092197597594.
# Iteration 58, Sum of Square Errors is 20.508329516162938.
# Iteration 59, Sum of Square Errors is 19.488287363497687.
# Iteration 60, Sum of Square Errors is 18.45450994638696.
# Iteration 61, Sum of Square Errors is 17.41152757918405.
# Iteration 62, Sum of Square Errors is 16.36457457247889.
# Iteration 63, Sum of Square Errors is 15.319452274939398.
# Iteration 64, Sum of Square Errors is 14.282367727721788.
# Iteration 65, Sum of Square Errors is 13.259751556070098.
# Iteration 66, Sum of Square Errors is 12.258061469505616.
# Iteration 67, Sum of Square Errors is 11.283580023226076.
# Iteration 68, Sum of Square Errors is 10.342216836141127.
# Iteration 69, Sum of Square Errors is 9.439326041851878.
# Iteration 70, Sum of Square Errors is 8.579549244569774.
# Iteration 71, Sum of Square Errors is 7.766692675924357.
# Iteration 72, Sum of Square Errors is 7.003644763030265.
# Iteration 73, Sum of Square Errors is 6.292337216517455.
# Iteration 74, Sum of Square Errors is 5.6337494092981135.
# Iteration 75, Sum of Square Errors is 5.027952645969165.
# Iteration 76, Sum of Square Errors is 4.474188278916694.
# Iteration 77, Sum of Square Errors is 3.9709717712968366.
# Iteration 78, Sum of Square Errors is 3.516213867733371.
# Iteration 79, Sum of Square Errors is 3.107350001651308.
# Iteration 80, Sum of Square Errors is 2.7414698168967804.
# Iteration 81, Sum of Square Errors is 2.4154400042281994.
# Iteration 82, Sum of Square Errors is 2.1260153093327836.
# Iteration 83, Sum of Square Errors is 1.8699343245063402.
# Iteration 84, Sum of Square Errors is 1.6439983361843835.
# Iteration 85, Sum of Square Errors is 1.4451329268454896.
# Iteration 86, Sum of Square Errors is 1.2704331449562654.
# Iteration 87, Sum of Square Errors is 1.1171938377225175.
# Iteration 88, Sum of Square Errors is 0.9829272076621068.
# Iteration 89, Sum of Square Errors is 0.865369851908531.
# Iteration 90, Sum of Square Errors is 0.7624815325237283.
# Iteration 91, Sum of Square Errors is 0.6724377689385939.
# Iteration 92, Sum of Square Errors is 0.5936180964199955.
# Iteration 93, Sum of Square Errors is 0.5245915438123342.
# Iteration 94, Sum of Square Errors is 0.464100584943139.
# Iteration 95, Sum of Square Errors is 0.4110445351981036.
# Iteration 96, Sum of Square Errors is 0.3644631125138431.
# Iteration 97, Sum of Square Errors is 0.32352066754223957.
# Iteration 98, Sum of Square Errors is 0.2874914126928004.
# Iteration 99, Sum of Square Errors is 0.2557458422405421.
# Iteration 100, Sum of Square Errors is 0.22773843167359678.
# Iteration 101, Sum of Square Errors is 0.20299662894445203.
# Iteration 102, Sum of Square Errors is 0.1811110980744549.
# Iteration 103, Sum of Square Errors is 0.16172714172325214.
# Iteration 104, Sum of Square Errors is 0.14453720951060367.
# Iteration 105, Sum of Square Errors is 0.12927438937801083.
# Iteration 106, Sum of Square Errors is 0.11570677709878975.
# Iteration 107, Sum of Square Errors is 0.10363262182227226.
# Iteration 108, Sum of Square Errors is 0.09287615146433285.
# Iteration 109, Sum of Square Errors is 0.08328398949364695.
# Iteration 110, Sum of Square Errors is 0.07472208325009456.
# Iteration 111, Sum of Square Errors is 0.06707307270389395.
# Iteration 112, Sum of Square Errors is 0.06023403708225635.
# Iteration 113, Sum of Square Errors is 0.05411456478332433.
# Iteration 114, Sum of Square Errors is 0.048635099314058024.
# Iteration 115, Sum of Square Errors is 0.04372552056379681.
# Iteration 116, Sum of Square Errors is 0.03932392654940313.
# Iteration 117, Sum of Square Errors is 0.03537558586902706.
# Iteration 118, Sum of Square Errors is 0.03183203552919705.
# Iteration 119, Sum of Square Errors is 0.028650302625374404.
# Iteration 120, Sum of Square Errors is 0.025792231624778457.
# Iteration 121, Sum of Square Errors is 0.023223901787495005.
# Iteration 122, Sum of Square Errors is 0.020915121629785156.
# Iteration 123, Sum of Square Errors is 0.018838989339237285.
# Iteration 124, Sum of Square Errors is 0.01697150974677734.
# Iteration 125, Sum of Square Errors is 0.015291259891187453.
# Iteration 126, Sum of Square Errors is 0.013779096417810962.
# Iteration 127, Sum of Square Errors is 0.012417899069236387.
# Iteration 128, Sum of Square Errors is 0.011192345381694828.
# Iteration 129, Sum of Square Errors is 0.010088712422112947.
# Iteration 130, Sum of Square Errors is 0.009094702008818099.
# Iteration 131, Sum of Square Errors is 0.008199286371945762.
# Iteration 132, Sum of Square Errors is 0.007392571643092272.
# Iteration 133, Sum of Square Errors is 0.0066656769304428015.
# Iteration 134, Sum of Square Errors is 0.006010627046370735.
# Iteration 135, Sum of Square Errors is 0.005420257218316754.
# Iteration 136, Sum of Square Errors is 0.004888128338175762.
# Iteration 137, Sum of Square Errors is 0.004408451496716146.
# Iteration 138, Sum of Square Errors is 0.003976020713018793.
# Iteration 139, Sum of Square Errors is 0.0035861529088854977.
# Iteration 140, Sum of Square Errors is 0.003234634298338082.
# Iteration 141, Sum of Square Errors is 0.0029176724657198503.
# Iteration 142, Sum of Square Errors is 0.002631853495123327.
# Iteration 143, Sum of Square Errors is 0.00237410359099896.
# Iteration 144, Sum of Square Errors is 0.0021416546966677007.
# Iteration 145, Sum of Square Errors is 0.001932013675576337.
# Iteration 146, Sum of Square Errors is 0.0017429346707353013.
# Iteration 147, Sum of Square Errors is 0.0015723943019696816.
# Iteration 148, Sum of Square Errors is 0.001418569399263962.
# Iteration 149, Sum of Square Errors is 0.0012798170043801678.
# Iteration 150, Sum of Square Errors is 0.0011546564026955225.
# Iteration 151, Sum of Square Errors is 0.0010417529734229828.
# Iteration 152, Sum of Square Errors is 0.0009399036694842622.
# Iteration 153, Sum of Square Errors is 0.0008480239587224799.
# Iteration 154, Sum of Square Errors is 0.0007651360762055796.
# Iteration 155, Sum of Square Errors is 0.0006903584533772117.
# Iteration 156, Sum of Square Errors is 0.0006228962040144728.
# Iteration 157, Sum of Square Errors is 0.0005620325595755423.
# Iteration 158, Sum of Square Errors is 0.0005071211577430275.
# Iteration 159, Sum of Square Errors is 0.000457579097975694.
# Iteration 160, Sum of Square Errors is 0.0004128806867889062.
# Iteration 161, Sum of Square Errors is 0.00037255180344910514.
# Iteration 162, Sum of Square Errors is 0.0003361648238690212.
# Iteration 163, Sum of Square Errors is 0.0003033340468486685.
# Iteration 164, Sum of Square Errors is 0.0002737115724896819.
# Iteration 165, Sum of Square Errors is 0.00024698358770016646.
# Iteration 166, Sum of Square Errors is 0.00022286701826962083.
# Iteration 167, Sum of Square Errors is 0.00020110651107578314.
# Iteration 168, Sum of Square Errors is 0.000181471713656365.
# Iteration 169, Sum of Square Errors is 0.00016375482166327643.
# Iteration 170, Sum of Square Errors is 0.00014776836767252624.
# Iteration 171, Sum of Square Errors is 0.00013334322747429343.
# Iteration 172, Sum of Square Errors is 0.00012032682234917969.
# Iteration 173, Sum of Square Errors is 0.00010858149797945025.
# Iteration 174, Sum of Square Errors is 9.798306256765646e-05.
# Iteration 175, Sum of Square Errors is 8.841946846724658e-05.
# Iteration 176, Sum of Square Errors is 7.978962318663046e-05.
# Iteration 177, Sum of Square Errors is 7.200231702864775e-05.
# Iteration 178, Sum of Square Errors is 6.497525588934355e-05.
# Iteration 179, Sum of Square Errors is 5.863418887387097e-05.
# Iteration 180, Sum of Square Errors is 5.291212140996617e-05.
# Iteration 181, Sum of Square Errors is 4.774860545859432e-05.
# Iteration 182, Sum of Square Errors is 4.308909925081974e-05.
# Iteration 183, Sum of Square Errors is 3.888438972544665e-05.
# Iteration 184, Sum of Square Errors is 3.509007151516489e-05.
# Iteration 185, Sum of Square Errors is 3.166607693357455e-05.
# Iteration 186, Sum of Square Errors is 2.8576251962333825e-05.
# Iteration 187, Sum of Square Errors is 2.5787973728387467e-05.
# Iteration 188, Sum of Square Errors is 2.327180540566991e-05.
# Iteration 189, Sum of Square Errors is 2.1001184873875145e-05.
# Iteration 190, Sum of Square Errors is 1.8952143827889398e-05.
# Iteration 191, Sum of Square Errors is 1.7103054356124916e-05.
# Iteration 192, Sum of Square Errors is 1.543440029737357e-05.
# Iteration 193, Sum of Square Errors is 1.3928570951629928e-05.
# Iteration 194, Sum of Square Errors is 1.256967495623859e-05.
# Iteration 195, Sum of Square Errors is 1.1343372354539972e-05.
# Iteration 196, Sum of Square Errors is 1.023672307692471e-05.
# Iteration 197, Sum of Square Errors is 9.23805022881305e-06.
# Iteration 198, Sum of Square Errors is 8.33681673738261e-06.
# Iteration 199, Sum of Square Errors is 7.523514050472888e-06.
# Iteration 200, Sum of Square Errors is 6.789561709393657e-06.
# Iteration 201, Sum of Square Errors is 6.127216732360237e-06.
# Iteration 202, Sum of Square Errors is 5.529491849572417e-06.
# Iteration 203, Sum of Square Errors is 4.99008172461326e-06.
# Iteration 204, Sum of Square Errors is 4.503296381737953e-06.
# Iteration 205, Sum of Square Errors is 4.0640011347644765e-06.
# Iteration 206, Sum of Square Errors is 3.667562382291288e-06.
# Iteration 207, Sum of Square Errors is 3.30979869596804e-06.
# Iteration 208, Sum of Square Errors is 2.986936684853542e-06.
# Iteration 209, Sum of Square Errors is 2.6955711690224832e-06.
# Iteration 210, Sum of Square Errors is 2.432629241750903e-06.
# Iteration 211, Sum of Square Errors is 2.1953378402261764e-06.
# Iteration 212, Sum of Square Errors is 1.9811944822262923e-06.
# Iteration 213, Sum of Square Errors is 1.78794085952031e-06.
# Iteration 214, Sum of Square Errors is 1.6135390090082194e-06.
# Iteration 215, Sum of Square Errors is 1.4561498098797586e-06.
# Iteration 216, Sum of Square Errors is 1.3141135796857918e-06.
# Iteration 217, Sum of Square Errors is 1.1859325643093696e-06.
# Iteration 218, Sum of Square Errors is 1.0702551370292666e-06.
# Iteration 219, Sum of Square Errors is 9.65861539703363e-07.
# Iteration 220, Sum of Square Errors is 8.71651015595916e-07.
# Iteration 221, Sum of Square Errors is 7.866301979429338e-07.
# Iteration 222, Sum of Square Errors is 7.099026317245082e-07.
# Iteration 223, Sum of Square Errors is 6.406593179465881e-07.
# Iteration 224, Sum of Square Errors is 5.781701807099817e-07.
# Iteration 225, Sum of Square Errors is 5.217763669138072e-07.
# Iteration 226, Sum of Square Errors is 4.708832974155084e-07.
# Iteration 227, Sum of Square Errors is 4.2495439619188744e-07.
# Iteration 228, Sum of Square Errors is 3.8350543144582957e-07.
# Iteration 229, Sum of Square Errors is 3.4609940883772335e-07.
# Iteration 230, Sum of Square Errors is 3.123419630198786e-07.
# Iteration 231, Sum of Square Errors is 2.818771988262773e-07.
# Iteration 232, Sum of Square Errors is 2.5438393822372684e-07.
# Iteration 233, Sum of Square Errors is 2.2957233345076248e-07.
# Iteration 234, Sum of Square Errors is 2.0718081059053227e-07.
# Iteration 235, Sum of Square Errors is 1.8697331135113945e-07.
# Iteration 236, Sum of Square Errors is 1.6873680393919676e-07.
# Iteration 237, Sum of Square Errors is 1.5227903678542026e-07.
# Iteration 238, Sum of Square Errors is 1.3742651140672392e-07.
# Iteration 239, Sum of Square Errors is 1.2402265304630508e-07.
# Iteration 240, Sum of Square Errors is 1.1192615977099005e-07.
# Iteration 241, Sum of Square Errors is 1.0100951263585867e-07.
# Iteration 242, Sum of Square Errors is 9.115763118165645e-08.
# Iteration 243, Sum of Square Errors is 8.226666009843011e-08.
# Iteration 244, Sum of Square Errors is 7.424287425730324e-08.
# Iteration 245, Sum of Square Errors is 6.700169055304996e-08.
# Iteration 246, Sum of Square Errors is 6.046677614765618e-08.
# Iteration 247, Sum of Square Errors is 5.456924370340824e-08.
# Iteration 248, Sum of Square Errors is 4.924692511934658e-08.
# Iteration 249, Sum of Square Errors is 4.44437161195769e-08.

# %%
#Compare the predicted and actual results
print(np.dot(user_mat, movie_mat).round())
print(ratings_mat)

np.dot(user_mat, movie_mat).round()==ratings_mat
# Out:
# [[10. 10. 10. 10.]
#  [10.  4.  9. 10.]
#  [ 8.  9. 10.  5.]
#  [ 9.  8. 10. 10.]
#  [10.  5.  9.  9.]
#  [ 6.  4. 10.  6.]
#  [ 9.  8. 10.  9.]
#  [10.  5.  9.  8.]
#  [ 7.  8. 10.  8.]
#  [ 9.  5.  9.  7.]
#  [ 9.  8. 10.  8.]
#  [ 9. 10. 10.  9.]
#  [10.  9. 10.  8.]
#  [ 5.  8.  5.  8.]
#  [10.  8. 10. 10.]
#  [ 9.  9. 10. 10.]
#  [ 9.  8.  8.  8.]
#  [10.  8.  1. 10.]
#  [ 5.  6. 10. 10.]
#  [ 8.  7. 10.  7.]]
# [[10. 10. 10. 10.]
#  [10.  4.  9. 10.]
#  [ 8.  9. 10.  5.]
#  [ 9.  8. 10. 10.]
#  [10.  5.  9.  9.]
#  [ 6.  4. 10.  6.]
#  [ 9.  8. 10.  9.]
#  [10.  5.  9.  8.]
#  [ 7.  8. 10.  8.]
#  [ 9.  5.  9.  7.]
#  [ 9.  8. 10.  8.]
#  [ 9. 10. 10.  9.]
#  [10.  9. 10.  8.]
#  [ 5.  8.  5.  8.]
#  [10.  8. 10. 10.]
#  [ 9.  9. 10. 10.]
#  [ 9.  8.  8.  8.]
#  [10.  8.  1. 10.]
#  [ 5.  6. 10. 10.]
#  [ 8.  7. 10.  7.]]
# matrix([[ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True],
#         [ True,  True,  True,  True]])

# %% [markdown]
# **With 250 iterations, the FunkSVD method converges to the input data.**

# %% [markdown]
# The last time we placed an **np.nan** value into this matrix the entire svd algorithm in python broke.  Let's see if that is still the case using your FunkSVD function.  In the below cell, I have placed a nan into the first cell of your numpy array.
#
# `4.` Use 4 latent features, a learning rate of 0.005, and 160 iterations.

# %%
# Here we are placing a nan into our original subset matrix
ratings_mat[0, 0] = np.nan
ratings_mat
# Out:
# matrix([[nan, 10., 10., 10.],
#         [10.,  4.,  9., 10.],
#         [ 8.,  9., 10.,  5.],
#         [ 9.,  8., 10., 10.],
#         [10.,  5.,  9.,  9.],
#         [ 6.,  4., 10.,  6.],
#         [ 9.,  8., 10.,  9.],
#         [10.,  5.,  9.,  8.],
#         [ 7.,  8., 10.,  8.],
#         [ 9.,  5.,  9.,  7.],
#         [ 9.,  8., 10.,  8.],
#         [ 9., 10., 10.,  9.],
#         [10.,  9., 10.,  8.],
#         [ 5.,  8.,  5.,  8.],
#         [10.,  8., 10., 10.],
#         [ 9.,  9., 10., 10.],
#         [ 9.,  8.,  8.,  8.],
#         [10.,  8.,  1., 10.],
#         [ 5.,  6., 10., 10.],
#         [ 8.,  7., 10.,  7.]])

# %%
# run SVD on the matrix with the missing value
# we pick the parameter iters=140 based on the gradient descent error reports
user_mat, movie_mat = FunkSVD(ratings_mat, latent_features=4, learning_rate=0.003, iters=170)
# Out:
# Optimization Statistics
# Iterations | Mean Squared Error
# Iteration 0, Sum of Square Errors is 4384.8268010163.
# Iteration 1, Sum of Square Errors is 2875.370382671522.
# Iteration 2, Sum of Square Errors is 1269.4701105474269.
# Iteration 3, Sum of Square Errors is 388.0331647812819.
# Iteration 4, Sum of Square Errors is 208.7159629007571.
# Iteration 5, Sum of Square Errors is 183.22470588059068.
# Iteration 6, Sum of Square Errors is 174.86690329985635.
# Iteration 7, Sum of Square Errors is 170.90015940908893.
# Iteration 8, Sum of Square Errors is 168.49540522090945.
# Iteration 9, Sum of Square Errors is 166.6563533095037.
# Iteration 10, Sum of Square Errors is 165.00430889335362.
# Iteration 11, Sum of Square Errors is 163.38509929016976.
# Iteration 12, Sum of Square Errors is 161.7301788541514.
# Iteration 13, Sum of Square Errors is 160.005307570013.
# Iteration 14, Sum of Square Errors is 158.19068162570426.
# Iteration 15, Sum of Square Errors is 156.27290126300804.
# Iteration 16, Sum of Square Errors is 154.24162026781178.
# Iteration 17, Sum of Square Errors is 152.08813949906195.
# Iteration 18, Sum of Square Errors is 149.8048467462421.
# Iteration 19, Sum of Square Errors is 147.3850438699314.
# Iteration 20, Sum of Square Errors is 144.8229622975198.
# Iteration 21, Sum of Square Errors is 142.11387776011026.
# Iteration 22, Sum of Square Errors is 139.25428247839974.
# Iteration 23, Sum of Square Errors is 136.24209323940437.
# Iteration 24, Sum of Square Errors is 133.0768818370908.
# Iteration 25, Sum of Square Errors is 129.76011667530554.
# Iteration 26, Sum of Square Errors is 126.29540390989914.
# Iteration 27, Sum of Square Errors is 122.68871478962197.
# Iteration 28, Sum of Square Errors is 118.94858366812653.
# Iteration 29, Sum of Square Errors is 115.08625909503161.
# Iteration 30, Sum of Square Errors is 111.11578897952995.
# Iteration 31, Sum of Square Errors is 107.05402056986009.
# Iteration 32, Sum of Square Errors is 102.92049739339564.
# Iteration 33, Sum of Square Errors is 98.7372387554873.
# Iteration 34, Sum of Square Errors is 94.5283931252265.
# Iteration 35, Sum of Square Errors is 90.31976469359171.
# Iteration 36, Sum of Square Errors is 86.13822216747576.
# Iteration 37, Sum of Square Errors is 82.01100966017329.
# Iteration 38, Sum of Square Errors is 77.96499019265974.
# Iteration 39, Sum of Square Errors is 74.02586143109697.
# Iteration 40, Sum of Square Errors is 70.2173894272199.
# Iteration 41, Sum of Square Errors is 66.56070810820789.
# Iteration 42, Sum of Square Errors is 63.07372938956221.
# Iteration 43, Sum of Square Errors is 59.770701062342894.
# Iteration 44, Sum of Square Errors is 56.66193780230017.
# Iteration 45, Sum of Square Errors is 53.75373620087528.
# Iteration 46, Sum of Square Errors is 51.048469491542555.
# Iteration 47, Sum of Square Errors is 48.54484359092908.
# Iteration 48, Sum of Square Errors is 46.238284876236435.
# Iteration 49, Sum of Square Errors is 44.121422912003624.
# Iteration 50, Sum of Square Errors is 42.1846285549347.
# Iteration 51, Sum of Square Errors is 40.41656924935317.
# Iteration 52, Sum of Square Errors is 38.80474807358817.
# Iteration 53, Sum of Square Errors is 37.336000081209704.
# Iteration 54, Sum of Square Errors is 35.99692749140921.
# Iteration 55, Sum of Square Errors is 34.7742632355613.
# Iteration 56, Sum of Square Errors is 33.65515943751592.
# Iteration 57, Sum of Square Errors is 32.6274030842897.
# Iteration 58, Sum of Square Errors is 31.67956522514551.
# Iteration 59, Sum of Square Errors is 30.801092558670586.
# Iteration 60, Sum of Square Errors is 29.98235143313387.
# Iteration 61, Sum of Square Errors is 29.214634385786958.
# Iteration 62, Sum of Square Errors is 28.490138694345617.
# Iteration 63, Sum of Square Errors is 27.80192529732861.
# Iteration 64, Sum of Square Errors is 27.143865098179987.
# Iteration 65, Sum of Square Errors is 26.51057828061038.
# Iteration 66, Sum of Square Errors is 25.897370950964326.
# Iteration 67, Sum of Square Errors is 25.30017225967086.
# Iteration 68, Sum of Square Errors is 24.715474171458794.
# Iteration 69, Sum of Square Errors is 24.140275259216533.
# Iteration 70, Sum of Square Errors is 23.572029277899205.
# Iteration 71, Sum of Square Errors is 23.008598811832314.
# Iteration 72, Sum of Square Errors is 22.448213956249973.
# Iteration 73, Sum of Square Errors is 21.889435766832612.
# Iteration 74, Sum of Square Errors is 21.33112406629957.
# Iteration 75, Sum of Square Errors is 20.772409114840528.
# Iteration 76, Sum of Square Errors is 20.21266661492823.
# Iteration 77, Sum of Square Errors is 19.651495517840978.
# Iteration 78, Sum of Square Errors is 19.08869811906697.
# Iteration 79, Sum of Square Errors is 18.524261965239248.
# Iteration 80, Sum of Square Errors is 17.958343140967056.
# Iteration 81, Sum of Square Errors is 17.391250556046877.
# Iteration 82, Sum of Square Errors is 16.823430909347735.
# Iteration 83, Sum of Square Errors is 16.25545406324609.
# Iteration 84, Sum of Square Errors is 15.687998620418368.
# Iteration 85, Sum of Square Errors is 15.121837551965436.
# Iteration 86, Sum of Square Errors is 14.557823781268198.
# Iteration 87, Sum of Square Errors is 13.996875680741548.
# Iteration 88, Sum of Square Errors is 13.439962487844978.
# Iteration 89, Sum of Square Errors is 12.888089691394647.
# Iteration 90, Sum of Square Errors is 12.342284478479272.
# Iteration 91, Sum of Square Errors is 11.803581365226925.
# Iteration 92, Sum of Square Errors is 11.273008160515879.
# Iteration 93, Sum of Square Errors is 10.751572429833814.
# Iteration 94, Sum of Square Errors is 10.240248636444882.
# Iteration 95, Sum of Square Errors is 9.739966138663247.
# Iteration 96, Sum of Square Errors is 9.251598215493903.
# Iteration 97, Sum of Square Errors is 8.775952278645732.
# Iteration 98, Sum of Square Errors is 8.313761407720499.
# Iteration 99, Sum of Square Errors is 7.86567731829819.
# Iteration 100, Sum of Square Errors is 7.432264840981647.
# Iteration 101, Sum of Square Errors is 7.01399795471659.
# Iteration 102, Sum of Square Errors is 6.611257381454621.
# Iteration 103, Sum of Square Errors is 6.224329713077977.
# Iteration 104, Sum of Square Errors is 5.85340800698734.
# Iteration 105, Sum of Square Errors is 5.498593755248947.
# Iteration 106, Sum of Square Errors is 5.159900104867382.
# Iteration 107, Sum of Square Errors is 4.837256184489168.
# Iteration 108, Sum of Square Errors is 4.530512376242726.
# Iteration 109, Sum of Square Errors is 4.239446360765394.
# Iteration 110, Sum of Square Errors is 3.9637697587379765.
# Iteration 111, Sum of Square Errors is 3.703135193151619.
# Iteration 112, Sum of Square Errors is 3.4571436025462314.
# Iteration 113, Sum of Square Errors is 3.225351645882652.
# Iteration 114, Sum of Square Errors is 3.0072790537171237.
# Iteration 115, Sum of Square Errors is 2.8024157970465016.
# Iteration 116, Sum of Square Errors is 2.610228963685322.
# Iteration 117, Sum of Square Errors is 2.430169251456756.
# Iteration 118, Sum of Square Errors is 2.261677007038578.
# Iteration 119, Sum of Square Errors is 2.104187758316441.
# Iteration 120, Sum of Square Errors is 1.9571372059937704.
# Iteration 121, Sum of Square Errors is 1.8199656565546634.
# Iteration 122, Sum of Square Errors is 1.692121893166835.
# Iteration 123, Sum of Square Errors is 1.5730664935597354.
# Iteration 124, Sum of Square Errors is 1.4622746142440937.
# Iteration 125, Sum of Square Errors is 1.3592382686700626.
# Iteration 126, Sum of Square Errors is 1.2634681331455906.
# Iteration 127, Sum of Square Errors is 1.1744949187050424.
# Iteration 128, Sum of Square Errors is 1.0918703498211717.
# Iteration 129, Sum of Square Errors is 1.0151677921056022.
# Iteration 130, Sum of Square Errors is 0.9439825711691334.
# Iteration 131, Sum of Square Errors is 0.8779320238373471.
# Iteration 132, Sum of Square Errors is 0.8166553211530911.
# Iteration 133, Sum of Square Errors is 0.7598131002435552.
# Iteration 134, Sum of Square Errors is 0.7070869393631208.
# Iteration 135, Sum of Square Errors is 0.6581787073984764.
# Iteration 136, Sum of Square Errors is 0.6128098159706062.
# Iteration 137, Sum of Square Errors is 0.5707203990965182.
# Iteration 138, Sum of Square Errors is 0.531668442267555.
# Iteration 139, Sum of Square Errors is 0.49542887982625466.
# Iteration 140, Sum of Square Errors is 0.4617926767270448.
# Iteration 141, Sum of Square Errors is 0.43056590818018553.
# Iteration 142, Sum of Square Errors is 0.401568848321592.
# Iteration 143, Sum of Square Errors is 0.37463507693260917.
# Iteration 144, Sum of Square Errors is 0.34961061135276494.
# Iteration 145, Sum of Square Errors is 0.3263530690789689.
# Iteration 146, Sum of Square Errors is 0.304730865115162.
# Iteration 147, Sum of Square Errors is 0.2846224469122656.
# Iteration 148, Sum of Square Errors is 0.26591556870337746.
# Iteration 149, Sum of Square Errors is 0.24850660617520126.
# Iteration 150, Sum of Square Errors is 0.2322999117062185.
# Iteration 151, Sum of Square Errors is 0.21720720982699193.
# Iteration 152, Sum of Square Errors is 0.20314703210156398.
# Iteration 153, Sum of Square Errors is 0.19004419027495587.
# Iteration 154, Sum of Square Errors is 0.1778292862656285.
# Iteration 155, Sum of Square Errors is 0.16643825739000945.
# Iteration 156, Sum of Square Errors is 0.15581195507664394.
# Iteration 157, Sum of Square Errors is 0.14589575524953852.
# Iteration 158, Sum of Square Errors is 0.13663919852428116.
# Iteration 159, Sum of Square Errors is 0.12799565835849325.
# Iteration 160, Sum of Square Errors is 0.11992203532279166.
# Iteration 161, Sum of Square Errors is 0.11237847570387288.
# Iteration 162, Sum of Square Errors is 0.1053281127123474.
# Iteration 163, Sum of Square Errors is 0.09873682864030953.
# Iteration 164, Sum of Square Errors is 0.09257303639374959.
# Iteration 165, Sum of Square Errors is 0.08680747890996314.
# Iteration 166, Sum of Square Errors is 0.08141304505766478.
# Iteration 167, Sum of Square Errors is 0.0763646007057045.
# Iteration 168, Sum of Square Errors is 0.07163883373368661.
# Iteration 169, Sum of Square Errors is 0.06721411184320304.

# %%
# this cell shows that we are able to predict for the missing value
preds = np.dot(user_mat, movie_mat)
print("The predicted value for the missing rating is {}:".format(preds[0,0]))
print()
print("The actual value for the missing rating is {}:".format(ratings_mat[0,0]))

print("We just predicted a rating for a user-movie pair that was never rated!")
print("If we look in the original matrix, this was actually a value of 10. Not bad!")
# Out:
# The predicted value for the missing rating is 10.339980448147628:
#
# The actual value for the missing rating is nan:
# We just predicted a rating for a user-movie pair that was never rated!
# If we look in the original matrix, this was actually a value of 10. Not bad!

# %% [markdown]
# Now let's extend this to a more realistic example. Unfortunately, running this function on a realistic user-movie matrix is still not something we likely be able to do on local machine.  However, we can see how well this example extends to 1000 users.
#
# `5.` Given the size of this matrix, this will take quite a bit of time.  We start with the following hyperparameters: 4 latent features, 0.0001 learning rate, and 20 iterations.

# %%
# Setting up a matrix of the first 1000 users with movie ratings
first_1000_users = np.matrix(user_by_movie.head(1000))

# perform funkSVD on the matrix of the top 1000 users
# since the size of input data increase, we choose a smaller learing rate = 0.0001
user_mat, movie_mat = FunkSVD(first_1000_users, latent_features=4, learning_rate=0.0001, iters=20)
# Out:
# Optimization Statistics
# Iterations | Mean Squared Error
# Iteration 0, Sum of Square Errors is 491846.0608011803.
# Iteration 1, Sum of Square Errors is 475409.5593923182.
# Iteration 2, Sum of Square Errors is 459325.3300650695.
# Iteration 3, Sum of Square Errors is 443581.3046262823.
# Iteration 4, Sum of Square Errors is 428180.6129619386.
# Iteration 5, Sum of Square Errors is 413138.1177543705.
# Iteration 6, Sum of Square Errors is 398477.13146615133.
# Iteration 7, Sum of Square Errors is 384226.3036802334.
# Iteration 8, Sum of Square Errors is 370416.7168794455.
# Iteration 9, Sum of Square Errors is 357079.2592528531.
# Iteration 10, Sum of Square Errors is 344242.35451722774.
# Iteration 11, Sum of Square Errors is 331930.1224526031.
# Iteration 12, Sum of Square Errors is 320161.0229222469.
# Iteration 13, Sum of Square Errors is 308947.0052450753.
# Iteration 14, Sum of Square Errors is 298293.14961641736.
# Iteration 15, Sum of Square Errors is 288197.75364764425.
# Iteration 16, Sum of Square Errors is 278652.78995240293.
# Iteration 17, Sum of Square Errors is 269644.64332288667.
# Iteration 18, Sum of Square Errors is 261155.02965827775.
# Iteration 19, Sum of Square Errors is 253162.0027324517.

# %%
# iters=20 was not too bad, and we saw the error is decreasing steadily but a bit slow.
# try learning rate = 0.0005, iters=100
user_mat, movie_mat = FunkSVD(first_1000_users, latent_features=4, learning_rate=0.0005, iters=100)
# Out:
# Optimization Statistics
# Iterations | Mean Squared Error
# Iteration 0, Sum of Square Errors is 489343.7798939081.
# Iteration 1, Sum of Square Errors is 404325.03625786636.
# Iteration 2, Sum of Square Errors is 331101.6110006428.
# Iteration 3, Sum of Square Errors is 274233.1102668536.
# Iteration 4, Sum of Square Errors is 233370.6804447274.
# Iteration 5, Sum of Square Errors is 204214.7163234572.
# Iteration 6, Sum of Square Errors is 182639.06216156867.
# Iteration 7, Sum of Square Errors is 165997.85547260824.
# Iteration 8, Sum of Square Errors is 152714.66070486946.
# Iteration 9, Sum of Square Errors is 141814.620873554.
# Iteration 10, Sum of Square Errors is 132666.5929917988.
# Iteration 11, Sum of Square Errors is 124846.71733890435.
# Iteration 12, Sum of Square Errors is 118060.94905786942.
# Iteration 13, Sum of Square Errors is 112098.96390800794.
# Iteration 14, Sum of Square Errors is 106806.0374337026.
# Iteration 15, Sum of Square Errors is 102065.48298146496.
# Iteration 16, Sum of Square Errors is 97787.37905643233.
# Iteration 17, Sum of Square Errors is 93901.1195034611.
# Iteration 18, Sum of Square Errors is 90350.35130639681.
# Iteration 19, Sum of Square Errors is 87089.4483084851.
# Iteration 20, Sum of Square Errors is 84081.00088750853.
# Iteration 21, Sum of Square Errors is 81293.99417331636.
# Iteration 22, Sum of Square Errors is 78702.46263180197.
# Iteration 23, Sum of Square Errors is 76284.48013433162.
# Iteration 24, Sum of Square Errors is 74021.39010900186.
# Iteration 25, Sum of Square Errors is 71897.210119488.
# Iteration 26, Sum of Square Errors is 69898.16506161849.
# Iteration 27, Sum of Square Errors is 68012.3166028779.
# Iteration 28, Sum of Square Errors is 66229.2656926185.
# Iteration 29, Sum of Square Errors is 64539.91133758232.
# Iteration 30, Sum of Square Errors is 62936.253284809536.
# Iteration 31, Sum of Square Errors is 61411.22939261127.
# Iteration 32, Sum of Square Errors is 59958.580710610266.
# Iteration 33, Sum of Square Errors is 58572.738909617765.
# Iteration 34, Sum of Square Errors is 57248.731889905044.
# Iteration 35, Sum of Square Errors is 55982.10428058842.
# Iteration 36, Sum of Square Errors is 54768.85021112175.
# Iteration 37, Sum of Square Errors is 53605.35624855004.
# Iteration 38, Sum of Square Errors is 52488.35279290023.
# Iteration 39, Sum of Square Errors is 51414.87253710068.
# Iteration 40, Sum of Square Errors is 50382.2148477631.
# Iteration 41, Sum of Square Errors is 49387.91512393784.
# Iteration 42, Sum of Square Errors is 48429.7183534626.
# Iteration 43, Sum of Square Errors is 47505.556218859994.
# Iteration 44, Sum of Square Errors is 46613.52721307556.
# Iteration 45, Sum of Square Errors is 45751.87931439022.
# Iteration 46, Sum of Square Errors is 44918.994843279455.
# Iteration 47, Sum of Square Errors is 44113.37718476119.
# Iteration 48, Sum of Square Errors is 43333.6391101466.
# Iteration 49, Sum of Square Errors is 42578.49247399811.
# Iteration 50, Sum of Square Errors is 41846.7390969621.
# Iteration 51, Sum of Square Errors is 41137.26267424608.
# Iteration 52, Sum of Square Errors is 40449.021573821534.
# Iteration 53, Sum of Square Errors is 39781.04240878369.
# Iteration 54, Sum of Square Errors is 39132.41428536378.
# Iteration 55, Sum of Square Errors is 38502.28364241609.
# Iteration 56, Sum of Square Errors is 37889.8496102538.
# Iteration 57, Sum of Square Errors is 37294.359826861786.
# Iteration 58, Sum of Square Errors is 36715.1066580854.
# Iteration 59, Sum of Square Errors is 36151.42377564271.
# Iteration 60, Sum of Square Errors is 35602.683052955326.
# Iteration 61, Sum of Square Errors is 35068.29174400605.
# Iteration 62, Sum of Square Errors is 34547.689914882954.
# Iteration 63, Sum of Square Errors is 34040.34810145781.
# Iteration 64, Sum of Square Errors is 33545.76516990049.
# Iteration 65, Sum of Square Errors is 33063.46635951558.
# Iteration 66, Sum of Square Errors is 32593.001489794475.
# Iteration 67, Sum of Square Errors is 32133.94331564868.
# Iteration 68, Sum of Square Errors is 31685.886016591412.
# Iteration 69, Sum of Square Errors is 31248.443807198062.
# Iteration 70, Sum of Square Errors is 30821.24965754455.
# Iteration 71, Sum of Square Errors is 30403.95411351436.
# Iteration 72, Sum of Square Errors is 29996.22420792046.
# Iteration 73, Sum of Square Errors is 29597.742454308795.
# Iteration 74, Sum of Square Errors is 29208.205916132625.
# Iteration 75, Sum of Square Errors is 28827.32534470899.
# Iteration 76, Sum of Square Errors is 28454.824380014878.
# Iteration 77, Sum of Square Errors is 28090.43880895475.
# Iteration 78, Sum of Square Errors is 27733.91587624308.
# Iteration 79, Sum of Square Errors is 27385.01364350609.
# Iteration 80, Sum of Square Errors is 27043.500392617214.
# Iteration 81, Sum of Square Errors is 26709.154069651002.
# Iteration 82, Sum of Square Errors is 26381.76176617217.
# Iteration 83, Sum of Square Errors is 26061.11923487689.
# Iteration 84, Sum of Square Errors is 25747.030436872043.
# Iteration 85, Sum of Square Errors is 25439.307118121997.
# Iteration 86, Sum of Square Errors is 25137.768412813082.
# Iteration 87, Sum of Square Errors is 24842.24047158391.
# Iteration 88, Sum of Square Errors is 24552.556112749153.
# Iteration 89, Sum of Square Errors is 24268.55449480732.
# Iteration 90, Sum of Square Errors is 23990.080808671257.
# Iteration 91, Sum of Square Errors is 23716.985988190212.
# Iteration 92, Sum of Square Errors is 23449.126437656163.
# Iteration 93, Sum of Square Errors is 23186.363775095535.
# Iteration 94, Sum of Square Errors is 22928.56459024479.
# Iteration 95, Sum of Square Errors is 22675.600216201317.
# Iteration 96, Sum of Square Errors is 22427.34651382012.
# Iteration 97, Sum of Square Errors is 22183.6836680026.
# Iteration 98, Sum of Square Errors is 21944.495995090732.
# Iteration 99, Sum of Square Errors is 21709.671760640344.

# %% [markdown]
# `6.` Now that we have a set of predictions for each user-movie pair,  let's look at a few statistics about our results.

# %%
# How many actual ratings exist in first_1000_users
num_ratings = np.sum(~np.isnan(first_1000_users))
print(f"The number of actual ratings in the first_1000_users is {num_ratings}.")


# How many ratings did we make for user-movie pairs that didn't actually have ratings
ratings_for_missing = np.sum(np.isnan(first_1000_users))
print(f"The number of ratings made for user-movie pairs that didn't have ratings is {ratings_for_missing}")
# Out:
# The number of actual ratings in the first_1000_users is 10852.
# The number of ratings made for user-movie pairs that didn't have ratings is 31234148

# %%
# Test your results against the solution
assert num_ratings == 10852, "Oops!  The number of actual ratings doesn't quite look right."
assert ratings_for_missing == 31234148, "Oops!  The number of movie-user pairs that you made ratings for that didn't actually have ratings doesn't look right."

# Make sure you made predictions on all the missing user-movie pairs
preds = np.dot(user_mat, movie_mat)
assert np.isnan(preds).sum() == 0
print("Nice job!  Looks like you have predictions made for all the missing user-movie pairs! But I still have one question... How good are they?")
# Out:
# Nice job!  Looks like you have predictions made for all the missing user-movie pairs! But I still have one question... How good are they?
